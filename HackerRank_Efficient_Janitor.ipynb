# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
def efficientjanitor(n, weight, maxWeight):

  weight.sort()
  print(weight)

  count = 0; pointerL = 0; pointerR = len(weight) - 1

  while pointerL <= pointerR:
    if weight[pointerL] + weight[pointerR] <= 3:
      pointerL +=1
      pointerR -=1
    elif weight[pointerR] <= 3:
      pointerR -=1
    else:
      pointerR +=1
    count +=1
  return count 

n = 5
weight = [1.01, 1.99, 2.5, 1.5, 1.01]
maxWeight = 3
print(efficientjanitor(n, weight, maxWeight))

weight = [1.01, 1.01, 1.01, 1.4, 2.4]
maxWeight = 3
print(efficientjanitor(n, weight, maxWeight))
# Out:
# [1.01, 1.01, 1.5, 1.99, 2.5]
# 3
# [1.01, 1.01, 1.01, 1.4, 2.4]
# 3
